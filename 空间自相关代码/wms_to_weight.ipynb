# %%
import pandas as pd
from pysal.lib import weights
from scipy.sparse import csr_matrix
import scipy

# 读取SWM文件
swm_path = "D:\Lenovo\Desktop\云南大学\大创\复杂地形条件对空间关系构建的影响研究\data\构建权重矩阵示例数据\w_output.swm"
w = weights.W.from_file(swm_path,format='swm')
print(w.sparse)
# Out:
#   (0, 1)	0.25761750549530393
#   (0, 2)	0.11837045990177027
#   (0, 3)	0.1277720383426502
#   (0, 5)	0.05138902756130554
#   (0, 6)	0.020674647735822577
#   (0, 7)	0.2151451422446891
#   (0, 8)	0.024042053056666002
#   (0, 10)	0.042610069549611135
#   (0, 11)	0.012769795152661027
#   (0, 12)	0.01813869697041945
#   (0, 13)	0.039088806456713136
#   (0, 27)	0.014410900646279748
#   (0, 31)	0.021306105109728586
#   (0, 72)	0.021149630111189453
#   (0, 80)	0.015515121665189889
#   (1, 0)	0.2762501880137108
#   (1, 2)	0.16758908975883666
#   (1, 3)	0.053675332579546535
#   (1, 5)	0.0477305890608811
#   (1, 6)	0.015971987519241188
#   (1, 7)	0.124614592563864
#   (1, 8)	0.035515562183638355
#   (1, 9)	0.013604566157260075
#   (1, 10)	0.12430346854495626
#   (1, 11)	0.015326926988863442
#   :	:
#   (119, 120)	0.2714285244428269
#   (119, 121)	0.1701674233344072
#   (120, 36)	0.14376237783857085
#   (120, 118)	0.1317849908212813
#   (120, 119)	0.44200599406745644
# ...
